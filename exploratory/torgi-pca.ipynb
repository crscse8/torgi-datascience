# %%
install.packages("RSQLite")
library(devtools)
install_github("ggbiplot", "vqv")

# %%
library(ggbiplot)
library(DBI)

#con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/TORGI-GNSS-20180823T200537.325Z.gpkg")
#con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/TORGI-GNSS-20180824T142348.854Z.gpkg")
#con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/TORGI-GNSS-20180824T135305.220Z.gpkg")

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T035519.442Z.gpkg")
df1 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T042051.492Z.gpkg")
df2 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T045102.194Z.gpkg")
df3 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180904T171244.998Z.gpkg")
df4 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T042102.426Z.gpkg")
df5 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T042059.950Z.gpkg")
df6 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T034051.895Z.gpkg")
df7 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T045105.269Z.gpkg")
df8 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T034059.473Z.gpkg")
df9 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T033933.821Z.gpkg")
df10 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180904T170918.397Z.gpkg")
df11 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T042120.346Z.gpkg")
df12 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T044812.469Z.gpkg")
df13 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180904T171027.789Z.gpkg")
df12 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T044810.167Z.gpkg")
df13 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180905T042122.141Z.gpkg")
df14 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/usertest/steve/TORGI-GNSS-20180904T171203.098Z.gpkg")
df15 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

con <- dbConnect(RSQLite::SQLite(), "../minio/torgi/localtest/TORGI-GNSS-20180829T120158.876Z.gpkg")
df16 <- dbReadTable(con, "sat_data")
dbDisconnect(con)

df = rbind(df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16)

# %%
log.ir <- df[, c(4,5,10,11,20,21,24,25)]

# %%
ir.species <- df[, 3]
ir.pca <- prcomp(log.ir,
                 center = TRUE,
                 scale. = TRUE) 
print(ir.pca)
plot(ir.pca, type = "l")
summary(ir.pca)
# Out:
# Standard deviations (1, .., p=8):
# [1] 1.4208777 1.3880700 1.1726043 1.0029518 0.8433710 0.6122836 0.5834557
# [8] 0.4968588
#
# Rotation (n x k) = (8 x 8):
#                                 PC1         PC2         PC3         PC4
# cn0                      0.06629962  0.45520053  0.01359326 -0.41599060
# agc                      0.55002382 -0.04089035 -0.38601688 -0.14746774
# sat_time_nanos           0.58338753 -0.02310711 -0.33016395 -0.16884911
# sat_time_1sigma_nanos   -0.11125738 -0.60216632 -0.08558880 -0.28322714
# pseudorange_rate_mps     0.31584103 -0.13621681  0.65435268  0.09096893
# pseudorange_rate_1sigma -0.15361490 -0.57157148 -0.04748726 -0.34206335
# azimuth_deg             -0.45858372  0.19302748 -0.45048001 -0.07150221
# elevation_deg           -0.08189517  0.21324551  0.31797453 -0.75238435
#                                  PC5         PC6          PC7          PC8
# cn0                      0.753582122 -0.10357857 -0.079935268 -0.173665479
# ...

# %%
g <- ggbiplot(ir.pca, obs.scale = 1, var.scale = 1, 
              groups = ir.species, ellipse = TRUE, 
              circle = TRUE)
g <- g + scale_color_discrete(name = '')
g <- g + theme(legend.direction = 'horizontal', 
               legend.position = 'top')
print(g)
# Out:
# plot without title
